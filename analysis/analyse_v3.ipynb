# %% [markdown]
# ## Loading dependencies and data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd
from scipy.stats import pearsonr
import statsmodels.api as sm
import scipy.stats as stats

# Load the dataset
file = '../new-data/everything_merged_dataset_no_NULL_violent&sexual.csv'
data = pd.read_csv(file)

# Remove unnecessary "total"
rename_columns = {
    "Total Homicides per 1,000": "Homicides per 1,000",
    "Total Sexual Crimes per 1,000": "Sexual Crimes per 1,000",
    "Total Violent Crimes per 1,000": "Violent Crimes per 1,000",
    "Total law enforcement firearms per 1,000": "Law enforcement firearms per 1,000",
    "Total military firearms per 1,000": "Military firearms per 1,000"
}

# Apply renaming
data.rename(columns=rename_columns, inplace=True)

# %% [markdown]
# ## Visualize data
# Some visualization of data before analyses

# %%
# We use the columns with the per 1000 data
columns_per_1000 = [
    "Homicides per 1,000",
    "Sexual Crimes per 1,000",
    "Violent Crimes per 1,000",
    "Combined Crime Rate per 1,000",
    "Total Firearms per 1,000",
    "Estimate of firearms in civilian possession per 1,000",
    "Law enforcement firearms per 1,000",
    "Military firearms per 1,000"
]

# And now we create histograms to visualize distribution of data
for column in columns_per_1000:
    plt.figure(figsize=(8, 6))
    sns.histplot(data[column], bins=30, kde=True, color='blue')
    plt.title(f"Distribution of {column}")
    plt.xlabel(column)
    plt.ylabel("Frequency")
    plt.tight_layout()
    plt.show()

# %%
# Create world maps
file_path = "../new-data/geo/ne_110m_admin_0_countries.shx" # world map data
world = gpd.read_file(file_path)
world = world.rename(columns={"NAME": "Country"})

# Merge data with world map
map_data = world.merge(data, on="Country", how="left")

# Plot Combined Crime Rate per 1,000
plt.figure(figsize=(25, 20))
map_data.plot(
    column="Combined Crime Rate per 1,000",
    cmap="OrRd",
    legend=True,
    missing_kwds={"color": "lightgrey", "label": "No data"},
)
plt.title("Combined Crime Rate per 1,000 by Country")
plt.show()

# Plot Total firearms per 1,000 by Country
plt.figure(figsize=(25, 20))
map_data.plot(
    column="Total Firearms per 1,000",
    cmap="OrRd",
    legend=True,
    missing_kwds={"color": "lightgrey", "label": "No data"},
)
plt.title("Total firearms per 1,000 by Country")
plt.show()

# %% [markdown]
# ## Analyses of RQs
# This is a start I guess
#
# 1. What is the general relationship between total sum of weapons for each type of crime seperated and also all types of crime combined
# 2. group countries with similar gun stats together and check how their distributions compare
# 3. check if GDP could be a confounding variable (AKA, check relationship between GDP and crime stats)
# 4. Check if the presence of weapons in civilian hands changes stuff (check whether that could be a confounding variable too)
#
# As for question 2:
# - 3 that contain the % of type of firearm possesion
# - one that contains the distribution
# - column "firearm group" which is a way to group countries together that have a similar distribution, basically each country gets assigned a group number
#
# I printed the data so you guys can see
# It's not done yet but we can work with it maybe

# %% [markdown]
# ### **First off - grouping countries**:
# **I suggest that we group countries in 4 categories based on the total number of weapons per 1000 ppl (Low, Medium-Low, Medium-High, High). This way, we can have roughly equally-sized groups and will have variability withing the groups in terms of proportion of weapon ownership (some will have bigger proportion of civilian, military, or law enforcement), where the dominant ownership type will be recorded in a column. The current method for creating the groups is more precise in terms of having countries with similar total weapons in the same group, but we also have many more groups, some of them having only 2 members, which will make analysis more difficult.**

# %%
data["Total Firearms Group"] = pd.qcut(
    data["Total Firearms per 1,000"], q=4, labels=["Low", "Medium-Low", "Medium-High", "High"]
)

# I won't be using them it looks like because it causes some issues in the regression
data["Civilian Proportion"] = (
    data["Estimate of firearms in civilian possession per 1,000"] / data["Total Firearms per 1,000"]
) * 100
data["Military Proportion"] = (
    data["Military firearms per 1,000"] / data["Total Firearms per 1,000"]
) * 100
data["Law Enforcement Proportion"] = (
    data["Law enforcement firearms per 1,000"] / data["Total Firearms per 1,000"]
) * 100

data.head(10)
# Out:
#    ISO              Country Continent                        Subregion  Year  \
# 0  ALB              Albania    Europe                  Southern Europe  2018
# 1  DZA              Algeria    Africa                  Northern Africa  2018
# 2  ATG  Antigua and Barbuda  Americas  Latin America and the Caribbean  2018
# 3  ARG            Argentina  Americas  Latin America and the Caribbean  2018
# 4  ARM              Armenia      Asia                     Western Asia  2018
# 5  AUS            Australia   Oceania        Australia and New Zealand  2018
# 6  AUT              Austria    Europe                   Western Europe  2018
# 7  AZE           Azerbaijan      Asia                     Western Asia  2018
# 8  BHS              Bahamas  Americas  Latin America and the Caribbean  2018
# 9  BRB             Barbados  Americas  Latin America and the Caribbean  2018
#
#    Population  Estimate of firearms in civilian possession  \
# 0   2911000.0                                       350000
# 1  41064000.0                                       877000
# 2     94000.0                                         5000
# 3  44272000.0                                      3256000
# 4   3032000.0                                       186000
# 5  24642000.0                                      3573000
# 6   8592000.0                                      2577000
# 7   9974000.0                                       362000
# 8    397000.0                                        74000
# 9    286000.0                                        10000
#
#    Total law enforcement firearms  Total military firearms  \
# 0                           19000                  21750.0
# 1                          363000                 637720.0
# 2                             800                    438.0
# 3                          391000                 679770.0
# 4                           18000                 509240.0
# 5                           69000                 214520.0
# 6                           37900                 240880.0
# 7                           18000                 537920.0
# 8                            5000                   2470.0
# 9                            2000                   1675.0
#
#    Estimate of firearms in civilian possession per 1,000  ...  \
# 0                                         120.233597      ...
# 1                                          21.356906      ...
# 2                                          53.191489      ...
# 3                                          73.545356      ...
# 4                                          61.345646      ...
# 5                                         144.996348      ...
# 6                                         299.930168      ...
# 7                                          36.294365      ...
# 8                                         186.397985      ...
# 9                                          34.965035      ...
#
#    Sexual Crimes per 1,000  Violent Crimes per 1,000   Country GDP  \
# 0                 0.111645                  0.333219  1.537951e+10
# 1                 0.077757                  0.409191  1.945540e+11
# 2                 2.670213                  2.180851  1.661530e+09
# 3                 0.737870                  3.082603  5.248200e+11
# 4                 0.057388                  0.079815  1.245794e+10
# 5                 1.132903                  3.337473  1.427810e+12
# 6                 1.201466                  1.652700  4.525820e+11
# 7                 0.035091                  0.078003  4.711247e+10
# 8                 2.120907                 17.813602  1.261580e+10
# 9                 1.548951                  2.765734  5.629916e+09
#
#    Country GDP per 1,000  Combined Crime Rate per 1,000  \
# 0           5.283239e+06                       2.591206
# 1           4.737824e+06                       0.726938
# 2           1.767585e+07                      10.531915
# 3           1.185445e+07                       6.528506
# 4           4.108819e+06                       0.545185
# 5           5.794213e+07                       4.879109
# 6           5.267481e+07                       3.402817
# 7           4.723528e+06                       1.043112
# 8           3.177783e+07                      35.798489
# 9           1.968502e+07                      10.548951
#
#    Total Firearms per 1,000  Total Firearms Group  Civilian Proportion  \
# 0                134.232223            Medium-Low            89.571337
# 1                 45.726671                   Low            46.705579
# 2                 66.361702                   Low            80.153895
# 3                 97.731523            Medium-Low            75.252440
# 4                235.237467                  High            26.078178
# 5                156.501907           Medium-High            92.648294
# 6                332.376629                  High            90.238044
# 7                 92.031281            Medium-Low            39.436988
# 8                205.214106           Medium-High            90.830981
# 9                 47.814685                   Low            73.126143
#
#    Military Proportion  Law Enforcement Proportion
# 0             5.566219                    4.862444
# 1            33.962465                   19.331956
# 2             7.021481                   12.824623
# 3            15.710796                    9.036764
# 4            71.398127                    2.523695
# 5             5.562528                    1.789178
# 6             8.434823                    1.327133
# 7            58.602057                    1.960955
# 8             3.031791                    6.137228
# 9            12.248629                   14.625229
#
# [10 rows x 26 columns]

# %% [markdown]
# **Visualize the relationships between firearm-related variables and different crime types using scatterplots with fitted regression lines.** This tests whether the relationship between crime and weapons is non-linear. From the plots, some relationships seem to be slightly non-linear, but the current model is only linear, even though it seems to capture significant effects good enough. We can mention in the limitations and future improvements to better capture the relationships

# %%
# List of firearm-related variables
firearm_columns = [
    "Estimate of firearms in civilian possession per 1,000",
    "Law enforcement firearms per 1,000",
    "Military firearms per 1,000"
]

# Crime variables
crime_types = [
    "Homicides per 1,000",
    "Sexual Crimes per 1,000",
    "Violent Crimes per 1,000",
    "Combined Crime Rate per 1,000"
]

for crime in crime_types:
    for firearm in firearm_columns:
        plt.figure(figsize=(8, 5))
        sns.regplot(x=data[crime], y=data[firearm], scatter_kws={"alpha": 0.5}, line_kws={"color": "red"}, lowess=True)
        plt.title(f"{crime} vs {firearm}")
        plt.xlabel(f"{firearm}")
        plt.ylabel(f"{crime}")
        plt.show()

# %% [markdown]
# Plot to get an idea for each group how the weapons are roughly distributed

# %%
# Compute mean crime rates by firearm group & ownership proportions
crime_means_within_group = data.groupby("Total Firearms Group")[
    ["Estimate of firearms in civilian possession per 1,000",
    "Law enforcement firearms per 1,000",
    "Military firearms per 1,000",
     "Homicides per 1,000", "Sexual Crimes per 1,000", 
     "Violent Crimes per 1,000", "Combined Crime Rate per 1,000"]
].mean().reset_index()

# Plot bar chart for ownership proportions
plt.figure(figsize=(10, 6))
ownership_melted = crime_means_within_group.melt(id_vars="Total Firearms Group", value_vars=["Estimate of firearms in civilian possession per 1,000",
    "Law enforcement firearms per 1,000",
    "Military firearms per 1,000"])
sns.barplot(data=ownership_melted, x="Total Firearms Group", y="value", hue="variable", palette="Set2")

plt.title("Average Ownership Proportions Within Each Firearms Group")
plt.xlabel("Firearms Group")
plt.ylabel("Proportion (%)")
plt.legend(title="Ownership Type")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/9j/jqs2fbzx1nl_9hlbbtdrlqrr0000gn/T/ipykernel_598/391481081.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   crime_means_within_group = data.groupby("Total Firearms Group")[

# %% [markdown]
# **Key Takeaways:**
# - In countries with high total firearm ownership, most firearms are civilian-owned.
# - In low total firearm countries, the share of military firearms is higher.
# - Law enforcement firearms are consistently the least significant contributor.

# %% [markdown]
# # **Analysis for Question 1. What is the general relationship between the presence of firearms per country (total N firearms per 1000 citizens) and the amount of homocides, violent and sexual crimes?**
# ### Is there a statistically significant relationship between the total number of weapons per 1000 ppl and the types of crime (investigate for each crime separately and in total)

# %%
# Define crime-related columns and firearm-related column
crime_columns = ["Homicides per 1,000", "Sexual Crimes per 1,000", "Violent Crimes per 1,000", "Combined Crime Rate per 1,000"]
weapon_column = "Total Firearms per 1,000"

# Compute correlations and p-values
correlation_results = []
for crime in crime_columns:
    correlation, p_value = pearsonr(data[weapon_column], data[crime])
    correlation_results.append([crime, correlation, p_value])

# Convert results into a DataFrame
correlation_df = pd.DataFrame(correlation_results, columns=["Crime Type", "Correlation", "P-value"])

# Display correlation heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(
    correlation_df.set_index("Crime Type")[["Correlation"]],  # Select only correlation column
    annot=True,
    cmap="coolwarm",
    cbar=True,
    linewidths=0.5,
    fmt=".2f"
)
plt.title("Correlation Between Weapons and Crime Types")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Display p-value heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(
    correlation_df.set_index("Crime Type")[["P-value"]],  # Select only p-value column
    annot=True,
    cmap="Blues",  # Use a different colormap for clarity
    cbar=True,
    linewidths=0.5,
    fmt=".3f"
)
plt.title("P-values for Correlation Between Weapons and Crime Types")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Print results
print("Correlation and P-values:")
print(correlation_df)
# Out:
# Correlation and P-values:
#                       Crime Type  Correlation   P-value
# 0            Homicides per 1,000    -0.037922  0.745006
# 1        Sexual Crimes per 1,000     0.135527  0.243086
# 2       Violent Crimes per 1,000     0.105879  0.362665
# 3  Combined Crime Rate per 1,000     0.039386  0.735512

# %% [markdown]
# We can add such scatterplots to see the relationship between total weapons vs each crime type for the countries in different groups. I'll print one just to see how it goes, if we decide to use them, uncomment the code for the rest.

# %%
# Scatterplot: Total firearms vs. Homicides
plt.figure(figsize=(10, 6))
sns.scatterplot(
    x="Total Firearms per 1,000", 
    y="Homicides per 1,000", 
    data=data, 
    hue="Total Firearms Group", 
    palette="viridis", 
    s=100
)
plt.title("Total Firearms vs. Homicides per 1,000 People", fontsize=16)
plt.xlabel("Total Firearms per 1,000", fontsize=12)
plt.ylabel("Homicides per 1,000", fontsize=12)
plt.legend(title="Firearms Group")
plt.show()

'''# Repeat for Violent Crimes
plt.figure(figsize=(10, 6))
sns.scatterplot(
    x="Total Firearms per 1,000", 
    y="Total Violent Crimes per 1,000", 
    data=data, 
    hue="Total Firearms Group", 
    palette="coolwarm", 
    s=100
)
plt.title("Total Firearms vs. Violent Crimes per 1,000 People", fontsize=16)
plt.xlabel("Total Firearms per 1,000", fontsize=12)
plt.ylabel("Violent Crimes per 1,000", fontsize=12)
plt.legend(title="Firearms Group")
plt.show()

# Repeat for Sexual Crimes
plt.figure(figsize=(10, 6))
sns.scatterplot(
    x="Total Firearms per 1,000", 
    y="Total Sexual Crimes per 1,000", 
    data=data, 
    hue="Total Firearms Group", 
    palette="plasma", 
    s=100
)
plt.title("Total Firearms vs. Sexual Crimes per 1,000 People", fontsize=16)
plt.xlabel("Total Firearms per 1,000", fontsize=12)
plt.ylabel("Sexual Crimes per 1,000", fontsize=12)
plt.legend(title="Firearms Group")
plt.show()

# Repeat for Total Crimes
plt.figure(figsize=(10, 6))
sns.scatterplot(
    x="Total Firearms per 1,000", 
    y="Combined Crime Rate per 1,000", 
    data=data, 
    hue="Total Firearms Group", 
    palette="plasma", 
    s=100
)
plt.title("Total Firearms vs. Combined Crimes per 1,000 People", fontsize=16)
plt.xlabel("Total Firearms per 1,000", fontsize=12)
plt.ylabel("Combined Crimes per 1,000", fontsize=12)
plt.legend(title="Firearms Group")
plt.show()'''
# Out:
# '# Repeat for Violent Crimes\nplt.figure(figsize=(10, 6))\nsns.scatterplot(\n    x="Total Firearms per 1,000", \n    y="Total Violent Crimes per 1,000", \n    data=data, \n    hue="Total Firearms Group", \n    palette="coolwarm", \n    s=100\n)\nplt.title("Total Firearms vs. Violent Crimes per 1,000 People", fontsize=16)\nplt.xlabel("Total Firearms per 1,000", fontsize=12)\nplt.ylabel("Violent Crimes per 1,000", fontsize=12)\nplt.legend(title="Firearms Group")\nplt.show()\n\n# Repeat for Sexual Crimes\nplt.figure(figsize=(10, 6))\nsns.scatterplot(\n    x="Total Firearms per 1,000", \n    y="Total Sexual Crimes per 1,000", \n    data=data, \n    hue="Total Firearms Group", \n    palette="plasma", \n    s=100\n)\nplt.title("Total Firearms vs. Sexual Crimes per 1,000 People", fontsize=16)\nplt.xlabel("Total Firearms per 1,000", fontsize=12)\nplt.ylabel("Sexual Crimes per 1,000", fontsize=12)\nplt.legend(title="Firearms Group")\nplt.show()\n\n# Repeat for Total Crimes\nplt.figure(figsize=(10, 6))\nsns.scatterplot(\n    x="Total Firearms per 1,000", \n    y="Combined Crime Rate per 1,000", \n    data=data, \n    hue="Total Firearms Group", \n    palette="plasma", \n    s=100\n)\nplt.title("Total Firearms vs. Combined Crimes per 1,000 People", fontsize=16)\nplt.xlabel("Total Firearms per 1,000", fontsize=12)\nplt.ylabel("Combined Crimes per 1,000", fontsize=12)\nplt.legend(title="Firearms Group")\nplt.show()'

# %% [markdown]
# Regression analysis for total number of weapons vs different crime types. GDP is included too as a confounding variable.
#
# The analysis uses a Negative Binomial regression, which is appropriate for count-based crime data that typically exhibit overdispersion (variance > mean). The model includes the main effect of total firearms to examine whether higher firearm ownership increases or decreases crime rates. For combined crime rates, a quadratic term is included to capture potential non-linear relationships, where the effect of firearms on crime may change as firearm levels increase. Additionally, an interaction term between firearms and GDP tests whether the relationship between firearm ownership and crime varies depending on a country’s economic conditions.

# %%
# Define crimes and results storage
crime_types = [
    "Homicides per 1,000", 
    "Sexual Crimes per 1,000", 
    "Violent Crimes per 1,000", 
    "Combined Crime Rate per 1,000"
]
nb_results_final = {}

# Create interaction term and quadratic term (if applicable)
data["Total_Firearms_Squared"] = data["Total Firearms per 1,000"]**2
# Interaction term for exploring varying relationships based on economic conditions
data["Firearms_GDP_Interaction"] = data["Total Firearms per 1,000"] * data["Country GDP per 1,000"]

for crime in crime_types:
    if crime == "Combined Crime Rate per 1,000":
        X = data[[
            "Total Firearms per 1,000", 
            "Total_Firearms_Squared", 
            "Country GDP per 1,000", 
            "Firearms_GDP_Interaction"
        ]]
    else:
        X = data[[
            "Total Firearms per 1,000", 
            "Country GDP per 1,000", 
            "Firearms_GDP_Interaction"
        ]]
    
    X = sm.add_constant(X) 
    y = data[crime] 

    try:
        # Fit Negative Binomial regression
        model = sm.GLM(y, X, family=sm.families.NegativeBinomial()).fit()
        nb_results_final[crime] = model.summary()
    except Exception as e:
        print(f"Skipping {crime} due to error: {e}")

for crime, result in nb_results_final.items():
    print(f"\nNegative Binomial Regression Results for {crime}:\n")
    print(result)
# Out:
# Negative Binomial Regression Results for Homicides per 1,000:
#
#                   Generalized Linear Model Regression Results
# ===============================================================================
# Dep. Variable:     Homicides per 1,000   No. Observations:                   76
# Model:                             GLM   Df Residuals:                       72
# Model Family:         NegativeBinomial   Df Model:                            3
# Link Function:                     Log   Scale:                          1.0000
# Method:                           IRLS   Log-Likelihood:                -151.82
# Date:                 Thu, 30 Jan 2025   Deviance:                       96.454
# Time:                         16:53:36   Pearson chi2:                     171.
# No. Iterations:                     11   Pseudo R-squ. (CS):             0.1780
# Covariance Type:             nonrobust
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        1.3259      0.298      4.445      0.000       0.741       1.911
# Total Firearms per 1,000     0.0006      0.002      0.332      0.740      -0.003       0.004
# Country GDP per 1,000    -3.691e-08   1.12e-08     -3.303      0.001   -5.88e-08    -1.5e-08
# Firearms_GDP_Interaction  1.498e-11   3.41e-11      0.439      0.660   -5.19e-11    8.18e-11
# ============================================================================================
#
# Negative Binomial Regression Results for Sexual Crimes per 1,000:
#
#                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     Sexual Crimes per 1,000   No. Observations:                   76
# Model:                                 GLM   Df Residuals:                       72
# Model Family:             NegativeBinomial   Df Model:                            3
# Link Function:                         Log   Scale:                          1.0000
# Method:                               IRLS   Log-Likelihood:                -83.524
# Date:                     Thu, 30 Jan 2025   Deviance:                       23.029
# Time:                             16:53:36   Pearson chi2:                     26.3
# No. Iterations:                          6   Pseudo R-squ. (CS):             0.1163
# Covariance Type:                 nonrobust
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                       -0.8190      0.449     -1.823      0.068      -1.699       0.061
# Total Firearms per 1,000    -0.0009      0.003     -0.327      0.744      -0.006       0.004
# Country GDP per 1,000      2.29e-08   1.11e-08      2.059      0.039    1.11e-09    4.47e-08
# Firearms_GDP_Interaction   6.08e-12   4.74e-11      0.128      0.898   -8.67e-11    9.89e-11
# ============================================================================================
#
# Negative Binomial Regression Results for Violent Crimes per 1,000:
#
#                     Generalized Linear Model Regression Results
# ====================================================================================
# Dep. Variable:     Violent Crimes per 1,000   No. Observations:                   76
# Model:                                  GLM   Df Residuals:                       72
# Model Family:              NegativeBinomial   Df Model:                            3
# Link Function:                          Log   Scale:                          1.0000
# Method:                                IRLS   Log-Likelihood:                -134.50
# Date:                      Thu, 30 Jan 2025   Deviance:                       69.386
# Time:                              16:53:36   Pearson chi2:                     99.7
# No. Iterations:                          12   Pseudo R-squ. (CS):             0.1925
# Covariance Type:                  nonrobust
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                       -0.0017      0.350     -0.005      0.996      -0.688       0.685
# Total Firearms per 1,000    -0.0007      0.002     -0.333      0.739      -0.005       0.003
# Country GDP per 1,000      3.03e-08   9.14e-09      3.316      0.001    1.24e-08    4.82e-08
# Firearms_GDP_Interaction  8.071e-13   3.72e-11      0.022      0.983   -7.21e-11    7.37e-11
# ============================================================================================
#
# Negative Binomial Regression Results for Combined Crime Rate per 1,000:
#
#                        Generalized Linear Model Regression Results
# =========================================================================================
# Dep. Variable:     Combined Crime Rate per 1,000   No. Observations:                   76
# Model:                                       GLM   Df Residuals:                       71
# Model Family:                   NegativeBinomial   Df Model:                            4
# Link Function:                               Log   Scale:                          1.0000
# Method:                                     IRLS   Log-Likelihood:                -205.59
# Date:                           Thu, 30 Jan 2025   Deviance:                       78.945
# Time:                                   16:53:36   Pearson chi2:                     106.
# No. Iterations:                               12   Pseudo R-squ. (CS):            0.04428
# Covariance Type:                       nonrobust
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        1.5716      0.284      5.537      0.000       1.015       2.128
# Total Firearms per 1,000     0.0010      0.002      0.543      0.587      -0.003       0.004
# Total_Firearms_Squared   -5.425e-06   2.77e-06     -1.960      0.050   -1.08e-05   -8.68e-10
# Country GDP per 1,000    -1.499e-08   1.25e-08     -1.196      0.232   -3.95e-08    9.57e-09
# Firearms_GDP_Interaction  9.945e-11   5.45e-11      1.826      0.068   -7.32e-12    2.06e-10
# ============================================================================================
# /Users/esma/miniforge3/envs/mlvu/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# /Users/esma/miniforge3/envs/mlvu/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# /Users/esma/miniforge3/envs/mlvu/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# /Users/esma/miniforge3/envs/mlvu/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "

# %% [markdown]
# The results of the **Negative Binomial regression** suggest mixed effects of **total firearms per 1,000 people**, **GDP per 1,000**, and their interaction on various crime rates:
#
# 1. **Total Homicides:**
#    The coefficient for total firearms is not significant (p = 0.740), indicating no direct relationship between firearms and homicide rates. However, **GDP per 1,000** is significant (p = 0.001), with a negative effect, implying that higher GDP is associated with lower homicide rates. The interaction between firearms and GDP is not significant (p = 0.660).
#
# 2. **Total Sexual Crimes:**
#    Total firearms have no significant impact on sexual crime rates (p = 0.744), but **GDP per 1,000** shows a significant positive effect (p = 0.039), suggesting that higher economic development correlates with higher sexual crime rates. The interaction term is insignificant (p = 0.898).
#
# 3. **Total Violent Crimes:**
#    There is no significant direct effect of total firearms (p = 0.739). However, **GDP per 1,000** again shows a significant positive relationship with violent crime rates (p = 0.001). The interaction term is not significant (p = 0.983).
#
# 4. **Combined Crime Rate:**
#    Total firearms and the firearms-GDP interaction are not significant (p = 0.587 and p = 0.068, respectively). However, the **quadratic term for total firearms** is borderline significant (p = 0.050), suggesting a **non-linear relationship**, where combined crime rates initially increase with firearms but eventually decrease. GDP itself is not significant (p = 0.232).
#
# Overall, **GDP per capita consistently influences crime rates**, while total firearms have no direct linear effect except for **non-linear effects on combined crime rates**. The **interaction between firearms and GDP** does not show significant variation across crime types.

# %% [markdown]
# # **Analysis for Question 2. Compare countries with similar total weapon numbers per 1000 citizens but different distributions (e.g., more civilian vs. military-held weapons vs. law enforcement) to investigate differences in homicide and sexual assault rates. How do different proportions of the weapon ownership types affect crime rates?**

# %% [markdown]
# **For each group, what is the correlation of the different distributions with crime:**

# %%
within_group_correlation_dict = {}

for group in data["Total Firearms Group"].unique():
    subset = data[data["Total Firearms Group"] == group]  # Filter data per group
    
    # Compute correlation matrix
    correlation_matrix = subset[["Civilian Proportion", "Military Proportion", "Law Enforcement Proportion",
                                 "Homicides per 1,000", "Sexual Crimes per 1,000", 
                                 "Violent Crimes per 1,000", "Combined Crime Rate per 1,000"]].corr()

    # Extract only ownership vs. crime correlations
    ownership_crime_correlation = correlation_matrix.loc[
        ["Civilian Proportion", "Military Proportion", "Law Enforcement Proportion"], 
        ["Homicides per 1,000", "Sexual Crimes per 1,000", 
         "Violent Crimes per 1,000", "Combined Crime Rate per 1,000"]
    ]
    
    within_group_correlation_dict[group] = ownership_crime_correlation

    # heatmap
    plt.figure(figsize=(8, 5))
    sns.heatmap(ownership_crime_correlation, annot=True, cmap="coolwarm", linewidths=0.5)
    plt.title(f"Correlation Between Ownership and Crime in {group} Firearm Group")
    plt.xticks(rotation=90)
    plt.yticks(rotation=15)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## **Below is the statistical testing. I used Negative Binomial Regression. I have put ChatGPT-ed explanations of the regression analysis so you can get an idea what the different parts are doing. After the actual code and the results, there is another explanation that summarizes the findings, some of which show statistical significance, which is good. My main concern now is how to present the results in the report. I cannot think of many options for nice plots. Feel free to give ideas.**

# %% [markdown]
# ### **Explanation of the Regression Analysis Below**
#
# This analysis examines how different types of firearm ownership (civilian, law enforcement, and military) affect various crime rates, while accounting for differences across firearm groups (low, medium, high total firearms) and controlling for economic conditions (GDP). The **Negative Binomial regression model** is used to handle count-based crime data with overdispersion (variance > mean). Here's the breakdown of the key steps:
#
# ---
#
# ### **1. Interaction Terms and Variables Setup**
# - **Interaction terms** are created to explore how the effect of firearm ownership changes across different **total firearm groups**:
#   - **Civilian_Firearms_Interaction**: Civilian firearm ownership × firearm group code
#   - **LawEnforcement_Firearms_Interaction**: Law enforcement firearms × firearm group code
#   - **Military_Firearms_Interaction**: Military firearms × firearm group code
#
# These interactions allow the model to test whether countries with similar total firearm counts but **different firearm distributions** experience different crime patterns.
#
# - The **independent variables** (`X`) include:
#   - Main effects of firearm ownership types (civilian, military, law enforcement)
#   - Interaction terms to capture group-specific differences
#   - **GDP per 1,000** as a control variable to account for the role of economic conditions
#   - A **constant term** to model baseline crime levels
#
# ---
#
# ### **2. Negative Binomial Regression for Each Crime Type**
# - The model is applied to four types of crime rates as dependent variables (`y`):
#   - Total homicides per 1,000
#   - Total sexual crimes per 1,000
#   - Total violent crimes per 1,000
#   - Combined crime rate per 1,000
#
# For each crime type, the model estimates the relationship between firearm ownership and crime, accounting for the interaction effects of firearm groups and GDP.
#
# ---
#
# ### **3. Interpreting the Regression Output**
# - **Regression results** provide the coefficients, p-values, and confidence intervals for each variable:
#   - **Main effects:** Indicate whether civilian, military, or law enforcement firearms directly influence crime rates.
#   - **Interaction terms:** Show whether the effect of firearm ownership changes across different firearm groups (low, medium, high).
#   - **GDP:** Tests whether economic conditions independently influence crime rates.
#
# ---
#
# ### **4. Wald Test for Group Differences**
# - A **Wald test** is performed for the interaction terms to check if differences between total firearm groups (low, medium, high) are statistically significant.
# - If the Wald test is significant, it suggests that the relationship between firearm ownership and crime **varies across groups**.
#
# ---
#
# ### **Purpose and Takeaways**
# This analysis aims to determine:
# - Whether **different types of firearm ownership** (civilian, military, law enforcement) are associated with variations in crime rates.
# - Whether **countries grouped by total firearm levels** experience varying impacts on crime due to firearm ownership distributions.
# - How much of the relationship between firearms and crime is **modified by economic factors (GDP)**.
# The findings from the regression and Wald test will reveal whether group-specific or economic conditions significantly shape the firearm-crime relationship.

# %%
# Prepare interaction terms
data["Civilian_Firearms_Interaction"] = data["Estimate of firearms in civilian possession per 1,000"] * pd.Categorical(data["Total Firearms Group"]).codes
data["LawEnforcement_Firearms_Interaction"] = data["Law enforcement firearms per 1,000"] * pd.Categorical(data["Total Firearms Group"]).codes
data["Military_Firearms_Interaction"] = data["Military firearms per 1,000"] * pd.Categorical(data["Total Firearms Group"]).codes

# Independent variables with interactions and control for GDP
X = data[[
    "Estimate of firearms in civilian possession per 1,000",
    "Law enforcement firearms per 1,000",
    "Military firearms per 1,000",
    "Civilian_Firearms_Interaction",
    "LawEnforcement_Firearms_Interaction",
    "Military_Firearms_Interaction",
    "Country GDP per 1,000"
]]
X = sm.add_constant(X)

nb_results_combined = {}
crime_types = ["Homicides per 1,000", "Sexual Crimes per 1,000", 
               "Violent Crimes per 1,000", "Combined Crime Rate per 1,000"]

for crime in crime_types:
    y = data[crime]
    
    # Fit Negative Binomial regression with interaction terms
    model = sm.GLM(y, X, family=sm.families.NegativeBinomial()).fit()
    nb_results_combined[crime] = model
    
    print(f"\nCombined Negative Binomial Regression Results for {crime}:\n")
    print(model.summary())

    # Wald test for interaction terms to check if group differences are significant
    print("\nWald test for interaction terms:")
    print(model.wald_test_terms().summary_frame())
# Out:
# Combined Negative Binomial Regression Results for Homicides per 1,000:
#
#                   Generalized Linear Model Regression Results
# ===============================================================================
# Dep. Variable:     Homicides per 1,000   No. Observations:                   76
# Model:                             GLM   Df Residuals:                       68
# Model Family:         NegativeBinomial   Df Model:                            7
# Link Function:                     Log   Scale:                          1.0000
# Method:                           IRLS   Log-Likelihood:                -137.32
# Date:                 Thu, 30 Jan 2025   Deviance:                       67.442
# Time:                         16:53:36   Pearson chi2:                     90.3
# No. Iterations:                     10   Pseudo R-squ. (CS):             0.4388
# Covariance Type:             nonrobust
# =========================================================================================================================
#                                                             coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------
# const                                                     0.0915      0.480      0.191      0.849      -0.850       1.033
# Estimate of firearms in civilian possession per 1,000     0.0313      0.007      4.445      0.000       0.018       0.045
# Law enforcement firearms per 1,000                       -0.0018      0.046     -0.039      0.969      -0.092       0.089
# Military firearms per 1,000                              -0.0270      0.020     -1.354      0.176      -0.066       0.012
# Civilian_Firearms_Interaction                            -0.0096      0.002     -4.292      0.000      -0.014      -0.005
# LawEnforcement_Firearms_Interaction                       0.0087      0.029      0.298      0.765      -0.048       0.066
# Military_Firearms_Interaction                             0.0081      0.007      1.127      0.260      -0.006       0.022
# Country GDP per 1,000                                 -3.551e-08   1.03e-08     -3.461      0.001   -5.56e-08   -1.54e-08
# =========================================================================================================================
#
# Wald test for interaction terms:
#                                                                          chi2  \
# const                                                 [[0.03630277407751281]]
# Estimate of firearms in civilian possession per...     [[19.755950092718514]]
# Law enforcement firearms per 1,000                  [[0.0015409677012795551]]
# Military firearms per 1,000                             [[1.833711706401523]]
# Civilian_Firearms_Interaction                          [[18.423333098434664]]
# LawEnforcement_Firearms_Interaction                   [[0.08906785021158169]]
# Military_Firearms_Interaction                          [[1.2700029497157677]]
# Country GDP per 1,000                                  [[11.978889956029906]]
#
#                                                                    P>chi2  \
# const                                                  0.8488915893642964
# Estimate of firearms in civilian possession per...  8.798733870307852e-06
# Law enforcement firearms per 1,000                     0.9686869550105677
# Military firearms per 1,000                           0.17568976562680844
# Civilian_Firearms_Interaction                        1.76878786600875e-05
# LawEnforcement_Firearms_Interaction                    0.7653655524314285
# Military_Firearms_Interaction                          0.2597661265354538
# Country GDP per 1,000                                0.000538066266177079
#
#                                                     df constraint
# const                                                           1
# Estimate of firearms in civilian possession per...              1
# Law enforcement firearms per 1,000                              1
# Military firearms per 1,000                                     1
# Civilian_Firearms_Interaction                                   1
# LawEnforcement_Firearms_Interaction                             1
# Military_Firearms_Interaction                                   1
# Country GDP per 1,000                                           1
#
# Combined Negative Binomial Regression Results for Sexual Crimes per 1,000:
#
#                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     Sexual Crimes per 1,000   No. Observations:                   76
# Model:                                 GLM   Df Residuals:                       68
# Model Family:             NegativeBinomial   Df Model:                            7
# Link Function:                         Log   Scale:                          1.0000
# Method:                               IRLS   Log-Likelihood:                -82.511
# Date:                     Thu, 30 Jan 2025   Deviance:                       21.004
# Time:                             16:53:36   Pearson chi2:                     22.5
# No. Iterations:                          8   Pseudo R-squ. (CS):             0.1395
# Covariance Type:                 nonrobust
# =========================================================================================================================
#                                                             coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------
# const                                                    -1.1513      0.627     -1.835      0.066      -2.381       0.078
# Estimate of firearms in civilian possession per 1,000     0.0079      0.009      0.887      0.375      -0.010       0.025
# Law enforcement firearms per 1,000                        0.0159      0.062      0.258      0.797      -0.105       0.137
# Military firearms per 1,000                              -0.0118      0.017     -0.674      0.501      -0.046       0.022
# Civilian_Firearms_Interaction                            -0.0027      0.003     -0.948      0.343      -0.008       0.003
# LawEnforcement_Firearms_Interaction                      -0.0090      0.037     -0.241      0.809      -0.083       0.064
# Military_Firearms_Interaction                             0.0036      0.007      0.534      0.593      -0.010       0.017
# Country GDP per 1,000                                  2.583e-08   8.63e-09      2.994      0.003    8.92e-09    4.27e-08
# =========================================================================================================================
#
# Wald test for interaction terms:
#                                                                        chi2  \
# const                                                [[3.3679112588414077]]
# Estimate of firearms in civilian possession per...   [[0.7861182432578996]]
# Law enforcement firearms per 1,000                  [[0.06637010920206057]]
# Military firearms per 1,000                         [[0.45383567377706957]]
# Civilian_Firearms_Interaction                         [[0.899511178348741]]
# LawEnforcement_Firearms_Interaction                 [[0.05815859804798437]]
# Military_Firearms_Interaction                        [[0.2853578291870532]]
# Country GDP per 1,000                                  [[8.96464118370947]]
#
#                                                                    P>chi2  \
# const                                                 0.06647798933374788
# Estimate of firearms in civilian possession per...     0.3752764704370215
# Law enforcement firearms per 1,000                     0.7966971296919673
# Military firearms per 1,000                            0.5005190598524196
# Civilian_Firearms_Interaction                         0.34291281600660956
# LawEnforcement_Firearms_Interaction                    0.8094303844102907
# Military_Firearms_Interaction                          0.5932108167285064
# Country GDP per 1,000                               0.0027525475251292493
#
#                                                     df constraint
# const                                                           1
# Estimate of firearms in civilian possession per...              1
# Law enforcement firearms per 1,000                              1
# Military firearms per 1,000                                     1
# Civilian_Firearms_Interaction                                   1
# LawEnforcement_Firearms_Interaction                             1
# Military_Firearms_Interaction                                   1
# Country GDP per 1,000                                           1
#
# Combined Negative Binomial Regression Results for Violent Crimes per 1,000:
#
#                     Generalized Linear Model Regression Results
# ====================================================================================
# Dep. Variable:     Violent Crimes per 1,000   No. Observations:                   76
# Model:                                  GLM   Df Residuals:                       68
# Model Family:              NegativeBinomial   Df Model:                            7
# Link Function:                          Log   Scale:                          1.0000
# Method:                                IRLS   Log-Likelihood:                -127.46
# Date:                      Thu, 30 Jan 2025   Deviance:                       55.297
# Time:                              16:53:36   Pearson chi2:                     73.1
# No. Iterations:                          13   Pseudo R-squ. (CS):             0.3291
# Covariance Type:                  nonrobust
# =========================================================================================================================
#                                                             coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------
# const                                                    -0.8761      0.513     -1.706      0.088      -1.882       0.130
# Estimate of firearms in civilian possession per 1,000     0.0131      0.007      1.810      0.070      -0.001       0.027
# Law enforcement firearms per 1,000                        0.0282      0.047      0.603      0.546      -0.063       0.120
# Military firearms per 1,000                              -0.0074      0.014     -0.518      0.604      -0.035       0.021
# Civilian_Firearms_Interaction                            -0.0044      0.002     -1.913      0.056      -0.009       0.000
# LawEnforcement_Firearms_Interaction                       0.0160      0.030      0.540      0.589      -0.042       0.074
# Military_Firearms_Interaction                            -0.0002      0.006     -0.029      0.977      -0.011       0.011
# Country GDP per 1,000                                  3.529e-08   7.34e-09      4.810      0.000    2.09e-08    4.97e-08
# =========================================================================================================================
#
# Wald test for interaction terms:
#                                                                          chi2  \
# const                                                  [[2.9117633933294353]]
# Estimate of firearms in civilian possession per...     [[3.2750680711556384]]
# Law enforcement firearms per 1,000                     [[0.3637410086792974]]
# Military firearms per 1,000                           [[0.26877641088373583]]
# Civilian_Firearms_Interaction                             [[3.6608578014647]]
# LawEnforcement_Firearms_Interaction                     [[0.292124737548789]]
# Military_Firearms_Interaction                       [[0.0008630718692653328]]
# Country GDP per 1,000                                   [[23.13330290873553]]
#
#                                                                     P>chi2  \
# const                                                  0.08793567870185734
# Estimate of firearms in civilian possession per...     0.07034000845917102
# Law enforcement firearms per 1,000                      0.5464358802554119
# Military firearms per 1,000                             0.6041537495728407
# Civilian_Firearms_Interaction                          0.05570494645870687
# LawEnforcement_Firearms_Interaction                     0.5888621548285937
# Military_Firearms_Interaction                           0.9765630510184992
# Country GDP per 1,000                               1.5115000500795743e-06
#
#                                                     df constraint
# const                                                           1
# Estimate of firearms in civilian possession per...              1
# Law enforcement firearms per 1,000                              1
# Military firearms per 1,000                                     1
# Civilian_Firearms_Interaction                                   1
# LawEnforcement_Firearms_Interaction                             1
# Military_Firearms_Interaction                                   1
# Country GDP per 1,000                                           1
#
# Combined Negative Binomial Regression Results for Combined Crime Rate per 1,000:
#
#                        Generalized Linear Model Regression Results
# =========================================================================================
# Dep. Variable:     Combined Crime Rate per 1,000   No. Observations:                   76
# Model:                                       GLM   Df Residuals:                       68
# Model Family:                   NegativeBinomial   Df Model:                            7
# Link Function:                               Log   Scale:                          1.0000
# Method:                                     IRLS   Log-Likelihood:                -196.89
# Date:                           Thu, 30 Jan 2025   Deviance:                       61.541
# Time:                                   16:53:36   Pearson chi2:                     81.8
# No. Iterations:                               12   Pseudo R-squ. (CS):             0.2399
# Covariance Type:                       nonrobust
# =========================================================================================================================
#                                                             coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------
# const                                                     0.5454      0.416      1.311      0.190      -0.270       1.361
# Estimate of firearms in civilian possession per 1,000     0.0219      0.006      3.588      0.000       0.010       0.034
# Law enforcement firearms per 1,000                       -0.0009      0.042     -0.021      0.983      -0.082       0.081
# Military firearms per 1,000                              -0.0111      0.013     -0.883      0.377      -0.036       0.014
# Civilian_Firearms_Interaction                            -0.0070      0.002     -3.605      0.000      -0.011      -0.003
# LawEnforcement_Firearms_Interaction                       0.0111      0.025      0.441      0.659      -0.038       0.060
# Military_Firearms_Interaction                             0.0024      0.005      0.510      0.610      -0.007       0.012
# Country GDP per 1,000                                  1.058e-08   6.62e-09      1.599      0.110   -2.39e-09    2.36e-08
# =========================================================================================================================
#
# Wald test for interaction terms:
#                                                                          chi2  \
# const                                                  [[1.7184598125817263]]
# Estimate of firearms in civilian possession per...      [[12.87412292807425]]
# Law enforcement firearms per 1,000                  [[0.0004299948939058144]]
# Military firearms per 1,000                              [[0.78023464360467]]
# Civilian_Firearms_Interaction                          [[12.995273484420153]]
# LawEnforcement_Firearms_Interaction                   [[0.19455006070569814]]
# Military_Firearms_Interaction                          [[0.2596388486038683]]
# Country GDP per 1,000                                  [[2.5567319548780416]]
#
#                                                                     P>chi2  \
# const                                                  0.18989142166142392
# Estimate of firearms in civilian possession per...  0.00033315682611672237
# Law enforcement firearms per 1,000                      0.9834559974810484
# Military firearms per 1,000                            0.37706938704450954
# Civilian_Firearms_Interaction                        0.0003122782366533673
# LawEnforcement_Firearms_Interaction                     0.6591563175690158
# Military_Firearms_Interaction                           0.6103683792240568
# Country GDP per 1,000                                  0.10982539996433394
#
#                                                     df constraint
# const                                                           1
# Estimate of firearms in civilian possession per...              1
# Law enforcement firearms per 1,000                              1
# Military firearms per 1,000                                     1
# Civilian_Firearms_Interaction                                   1
# LawEnforcement_Firearms_Interaction                             1
# Military_Firearms_Interaction                                   1
# Country GDP per 1,000                                           1
# /Users/esma/miniforge3/envs/mlvu/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# /Users/esma/miniforge3/envs/mlvu/lib/python3.10/site-packages/statsmodels/base/model.py:1912: FutureWarning: The behavior of wald_test will change after 0.14 to returning scalar test statistic values. To get the future behavior now, set scalar to True. To silence this message while retaining the legacy behavior, set scalar to False.
#   warnings.warn(
# /Users/esma/miniforge3/envs/mlvu/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# /Users/esma/miniforge3/envs/mlvu/lib/python3.10/site-packages/statsmodels/base/model.py:1912: FutureWarning: The behavior of wald_test will change after 0.14 to returning scalar test statistic values. To get the future behavior now, set scalar to True. To silence this message while retaining the legacy behavior, set scalar to False.
#   warnings.warn(
# /Users/esma/miniforge3/envs/mlvu/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# /Users/esma/miniforge3/envs/mlvu/lib/python3.10/site-packages/statsmodels/base/model.py:1912: FutureWarning: The behavior of wald_test will change after 0.14 to returning scalar test statistic values. To get the future behavior now, set scalar to True. To silence this message while retaining the legacy behavior, set scalar to False.
#   warnings.warn(
# /Users/esma/miniforge3/envs/mlvu/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# /Users/esma/miniforge3/envs/mlvu/lib/python3.10/site-packages/statsmodels/base/model.py:1912: FutureWarning: The behavior of wald_test will change after 0.14 to returning scalar test statistic values. To get the future behavior now, set scalar to True. To silence this message while retaining the legacy behavior, set scalar to False.
#   warnings.warn(

# %% [markdown]
# ## **Explanation of the results from the regression. There are some good results. We cab summarize them in a table for the report!**
# ### **1. Total Homicides per 1,000**
# - **Civilian firearms:**
#   - Positive and **statistically significant** (`coef = 0.0313`, `P < 0.001`).
#   - This indicates that an increase in civilian firearms is associated with an increase in homicide rates across groups.
# - **Interaction (Civilian_Firearms_Interaction):**
#   - **Significant negative interaction** (`coef = -0.0096`, `P < 0.001`).
#   - This means that **the effect of civilian firearms on homicides decreases as the total firearms group changes** (e.g., in groups with higher total firearms).
#   - The Wald test confirms this difference is significant (`P < 0.001`).
# - **Military and law enforcement firearms:**
#   - Not statistically significant (`P > 0.1`), indicating no strong or consistent relationship across groups.
# - **Country GDP:**
#   - Negative and significant (`coef = -3.55e-08`, `P = 0.001`), indicating that higher GDP is associated with lower homicide rates.
#
# **Interpretation:**
# There is a strong, significant positive relationship between civilian firearms and homicides. However, this effect diminishes as the total firearms level in a group increases, likely due to a balancing effect between civilian, law enforcement, and military-held weapons.
#
# ---
#
# ### **2. Total Sexual Crimes per 1,000**
# - **Civilian firearms:**
#   - Not significant (`P = 0.375`), suggesting no consistent effect on sexual crimes.
# - **Interaction (Civilian_Firearms_Interaction):**
#   - Not significant (`P = 0.343`), meaning that variations in civilian firearms across groups do not significantly affect sexual crime rates.
# - **Law enforcement and military firearms:**
#   - Both insignificant (`P > 0.5`).
# - **Country GDP:**
#   - Significant and positive (`P = 0.003`), indicating that higher GDP is associated with higher reported sexual crime rates. This could reflect improved reporting mechanisms in wealthier nations.
#
# **Interpretation:**
# No clear relationship is found between firearm types and sexual crimes. GDP, however, plays a significant role, possibly due to reporting differences.
#
# ---
#
# ### **3. Total Violent Crimes per 1,000**
# - **Civilian firearms:**
#   - Positive but only marginally significant (`coef = 0.0131`, `P = 0.070`).
#   - Suggests a weak association between civilian firearms and violent crime rates.
# - **Interaction (Civilian_Firearms_Interaction):**
#   - Marginally significant (`P = 0.056`), suggesting that **the effect of civilian firearms on violent crimes varies across groups.**
#   - The negative coefficient implies that **the effect diminishes in higher-total-firearms groups.**
# - **Law enforcement and military firearms:**
#   - Not significant (`P > 0.5`).
# - **Country GDP:**
#   - Significant and positive (`P < 0.001`), indicating that higher GDP correlates with higher violent crime rates, potentially due to improved crime reporting.
#
# **Interpretation:**
# Civilian firearms have a weak effect on violent crimes, and this effect diminishes in higher-total-firearms groups. Higher GDP is consistently associated with increased reporting of violent crimes.
#
# ---
#
# ### **4. Combined Crime Rate per 1,000**
# - **Civilian firearms:**
#   - Significant and positive (`coef = 0.0219`, `P < 0.001`), meaning that an increase in civilian firearms is associated with higher overall crime rates.
# - **Interaction (Civilian_Firearms_Interaction):**
#   - **Significant negative interaction (`P < 0.001`)**
#   - This indicates that **the positive effect of civilian firearms on crime decreases across groups with higher total firearms.**
# - **Law enforcement and military firearms:**
#   - Not significant (`P > 0.3`), suggesting no major effect.
# - **Country GDP:**
#   - Marginally insignificant (`P = 0.110`), meaning GDP may not have a consistent effect on combined crimes.
#
# **Interpretation:**
# The overall crime rate increases with higher civilian firearms, but this effect diminishes in groups with higher total firearms. Law enforcement and military firearms have no significant influence on combined crime rates.
#
# ---
#
# ### **Key Takeaways**
# 1. **Civilian firearms have the most significant impact on crime, particularly homicides and combined crime rates.**
# 2. **The effect of civilian firearms decreases as the group’s total firearm level increases** (evidence from the significant interaction terms).
# 3. **Law enforcement and military firearms show little to no consistent impact.**
# 4. **GDP significantly affects crime types**, often acting as a confounding variable but providing insight into the role of economic development and reporting standards.
#
# ### **What this means for group differences**
# - The **significant interaction terms (e.g., for homicides and combined crime rates)** confirm that **group differences matter.**
# - For example, the Wald test shows that the effect of civilian firearms is **significantly different between groups.**
# - **Post-hoc comparisons** could further clarify which groups differ, but these results already indicate that groups with higher total firearms moderate the influence of civilian firearms on crime.
#
# **Based on the regression and Wald tests, the following key insights emerge:**
#
# *Homicides and Combined Crime Rate:*
# - Differences in firearm ownership distribution do matter, specifically when it comes to civilian firearms. Countries with higher civilian firearm proportions (within the same total weapon group) tend to have lower homicide rates and overall crime rates. This is a significant finding that supports part of your hypothesis.
# - Sexual Crimes and Violent Crimes:
# For these crime types, the results suggest that firearm distribution does not significantly explain variations. Instead, factors like GDP per capita (significant in the sexual crimes model) or other socio-economic variables could be more important.

# %% [markdown]
# ### **Visualizations for Q2 (Needs attention).**

# %% [markdown]
# ### More visualizations possibly needed. **Feel free to think what could be useful and add it!**

# %%
lst = ["Homicides per 1,000", "Sexual Crimes per 1,000", "Violent Crimes per 1,000"]

for i in lst: 
    plt.figure(figsize=(10, 6))
    sns.boxplot(data=data, x="Total Firearms Group", y=i, palette="coolwarm")
    plt.title(f"Distribution of {i} by Firearm Group")
    plt.xlabel("Total Firearms Group")
    plt.ylabel(f"Observed {i}")
    plt.show()
# Out:
# /var/folders/9j/jqs2fbzx1nl_9hlbbtdrlqrr0000gn/T/ipykernel_598/816179966.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x="Total Firearms Group", y=i, palette="coolwarm")
# /var/folders/9j/jqs2fbzx1nl_9hlbbtdrlqrr0000gn/T/ipykernel_598/816179966.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x="Total Firearms Group", y=i, palette="coolwarm")
# /var/folders/9j/jqs2fbzx1nl_9hlbbtdrlqrr0000gn/T/ipykernel_598/816179966.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x="Total Firearms Group", y=i, palette="coolwarm")

# %% [markdown]
# Not sure if useful

# %%
sns.lmplot(data=data, x="Estimate of firearms in civilian possession per 1,000", 
           y="Homicides per 1,000", hue="Total Firearms Group", 
           height=6, aspect=1.5, markers=["o", "s", "D", "X"], scatter_kws={'alpha':0.7})
plt.title("Observed Homicides vs. Civilian Firearms Across Groups")
plt.show()

# %% [markdown]
# # **Question 3. Check if GDP is a confounding variable**

# %%
# GDP as a Confounding Variable
gdp_column = "Country GDP per 1,000"

# Correlations between GDP and crime stats
gdp_crime_correlations = {}
for crime in ["Estimate of firearms in civilian possession per 1,000", "Law enforcement firearms per 1,000", "Military firearms per 1,000"]:
    correlation, _ = pearsonr(data[gdp_column], data[crime])
    gdp_crime_correlations[crime] = correlation

print("Correlations between GDP and weapon types:")
print(gdp_crime_correlations)

# Create heatmap
correlation_df = pd.DataFrame.from_dict(gdp_crime_correlations, orient='index', columns=['Correlation'])
plt.figure(figsize=(8, 6))
sns.heatmap(
    correlation_df,
    annot=True,
    cmap='coolwarm',
    cbar=True,
    linewidths=0.5
)
plt.title("Correlation Between GDP and Weapon Types")
plt.tight_layout()
plt.show()
# Out:
# Correlations between GDP and weapon types:
# {'Estimate of firearms in civilian possession per 1,000': 0.39204728257336885, 'Law enforcement firearms per 1,000': -0.1970300732533108, 'Military firearms per 1,000': -0.014619247140157738}

# %% [markdown]
# **Strong Positive Correlation – Wealthier countries have more civilian-owned firearms.**

# %%
# GDP as a Confounding Variable
gdp_column = "Country GDP per 1,000"

# Correlations between GDP and crime stats
gdp_crime_correlations = {}
for crime in crime_columns:
    correlation, _ = pearsonr(data[gdp_column], data[crime])
    gdp_crime_correlations[crime] = correlation

print("Correlations between GDP and crime types:")
print(gdp_crime_correlations)

# Create heatmap
correlation_df = pd.DataFrame.from_dict(gdp_crime_correlations, orient='index', columns=['Correlation'])
plt.figure(figsize=(8, 6))
sns.heatmap(
    correlation_df,
    annot=True,
    cmap='coolwarm',
    cbar=True,
    linewidths=0.5
)
plt.title("Correlation Between GDP and Crime Types")
plt.tight_layout()
plt.show()
# Out:
# Correlations between GDP and crime types:
# {'Homicides per 1,000': -0.1986104041527939, 'Sexual Crimes per 1,000': 0.5635179389395492, 'Violent Crimes per 1,000': 0.32204226855170603, 'Combined Crime Rate per 1,000': 0.07633304365629892}

# %% [markdown]
# ### **Final Answer: Is GDP a Confounder?**
# 1. **GDP strongly correlates with civilian firearm ownership** (**0.39**), meaning wealthier countries tend to have more civilian firearms.
# 2. **GDP significantly correlates with certain crime types**:
#    - **Negative correlation with homicides (-0.2)** → Higher GDP countries have fewer homicides.
#    - **Positive correlation with sexual crimes (0.56) and violent crimes (0.32)** → Wealthier countries report more of these crimes.
#
#
# ### **I include GDP in the regressions above so it should be taken care of**

# %% [markdown]
# ##  **Question 4. Idk if we should drop this question about the ratio of government vs civilian owned and the crime rates. Seems repetitive and I don't feel like doing all of the statistical stuff and plotting once again. We can try and answer this question with the things we already have.**

# %% [markdown]
# **Create the ratio between the two and run regression to see if the effect is significant**

# %%
# Create the government-to-civilian ratio variable
data["Gov_to_Civilian_Ratio"] = (data["Law enforcement firearms per 1,000"] + data["Military firearms per 1,000"]) / data["Estimate of firearms in civilian possession per 1,000"]

gov_ratio_results = {}
crime_types = ["Homicides per 1,000", "Sexual Crimes per 1,000", 
               "Violent Crimes per 1,000", "Combined Crime Rate per 1,000"]

# Define and fit the model for each crime type
for crime in crime_types:
    X = data[[
        "Gov_to_Civilian_Ratio",
        "Country GDP per 1,000"  # Control for economic conditions
    ]]
    
    X = sm.add_constant(X)  
    y = data[crime]  # Dependent variable: crime rate
    model = sm.GLM(y, X, family=sm.families.NegativeBinomial()).fit()
    gov_ratio_results[crime] = model.summary()  
    
    print(f"\nNegative Binomial Regression Results for {crime} (Gov-to-Civilian Ratio Analysis):\n")
    print(model.summary())
# Out:
# Negative Binomial Regression Results for Homicides per 1,000 (Gov-to-Civilian Ratio Analysis):
#
#                   Generalized Linear Model Regression Results
# ===============================================================================
# Dep. Variable:     Homicides per 1,000   No. Observations:                   76
# Model:                             GLM   Df Residuals:                       73
# Model Family:         NegativeBinomial   Df Model:                            2
# Link Function:                     Log   Scale:                          1.0000
# Method:                           IRLS   Log-Likelihood:                -145.87
# Date:                 Thu, 30 Jan 2025   Deviance:                       84.556
# Time:                         16:53:37   Pearson chi2:                 2.08e+10
# No. Iterations:                     11   Pseudo R-squ. (CS):             0.2971
# Covariance Type:             nonrobust
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     1.7273      0.242      7.132      0.000       1.253       2.202
# Gov_to_Civilian_Ratio    -0.8463      0.263     -3.214      0.001      -1.363      -0.330
# Country GDP per 1,000 -3.203e-08   8.51e-09     -3.763      0.000   -4.87e-08   -1.53e-08
# =========================================================================================
#
# Negative Binomial Regression Results for Sexual Crimes per 1,000 (Gov-to-Civilian Ratio Analysis):
#
#                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     Sexual Crimes per 1,000   No. Observations:                   76
# Model:                                 GLM   Df Residuals:                       73
# Model Family:             NegativeBinomial   Df Model:                            2
# Link Function:                         Log   Scale:                          1.0000
# Method:                               IRLS   Log-Likelihood:                -83.157
# Date:                     Thu, 30 Jan 2025   Deviance:                       22.295
# Time:                             16:53:37   Pearson chi2:                     25.3
# No. Iterations:                          5   Pseudo R-squ. (CS):             0.1247
# Covariance Type:                 nonrobust
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.9025      0.272     -3.321      0.001      -1.435      -0.370
# Gov_to_Civilian_Ratio    -0.0394      0.044     -0.900      0.368      -0.125       0.046
# Country GDP per 1,000  2.318e-08   7.59e-09      3.055      0.002    8.31e-09    3.81e-08
# =========================================================================================
#
# Negative Binomial Regression Results for Violent Crimes per 1,000 (Gov-to-Civilian Ratio Analysis):
#
#                     Generalized Linear Model Regression Results
# ====================================================================================
# Dep. Variable:     Violent Crimes per 1,000   No. Observations:                   76
# Model:                                  GLM   Df Residuals:                       73
# Model Family:              NegativeBinomial   Df Model:                            2
# Link Function:                          Log   Scale:                          1.0000
# Method:                                IRLS   Log-Likelihood:                -133.39
# Date:                      Thu, 30 Jan 2025   Deviance:                       67.169
# Time:                              16:53:37   Pearson chi2:                     94.4
# No. Iterations:                           9   Pseudo R-squ. (CS):             0.2157
# Covariance Type:                  nonrobust
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.0406      0.212     -0.191      0.849      -0.457       0.376
# Gov_to_Civilian_Ratio    -0.0567      0.036     -1.569      0.117      -0.128       0.014
# Country GDP per 1,000   2.92e-08   6.35e-09      4.602      0.000    1.68e-08    4.16e-08
# =========================================================================================
#
# Negative Binomial Regression Results for Combined Crime Rate per 1,000 (Gov-to-Civilian Ratio Analysis):
#
#                        Generalized Linear Model Regression Results
# =========================================================================================
# Dep. Variable:     Combined Crime Rate per 1,000   No. Observations:                   76
# Model:                                       GLM   Df Residuals:                       73
# Model Family:                   NegativeBinomial   Df Model:                            2
# Link Function:                               Log   Scale:                          1.0000
# Method:                                     IRLS   Log-Likelihood:                -204.98
# Date:                           Thu, 30 Jan 2025   Deviance:                       77.732
# Time:                                   16:53:37   Pearson chi2:                     106.
# No. Iterations:                                8   Pseudo R-squ. (CS):            0.05941
# Covariance Type:                       nonrobust
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     1.5519      0.173      8.954      0.000       1.212       1.892
# Gov_to_Civilian_Ratio    -0.0624      0.033     -1.896      0.058      -0.127       0.002
# Country GDP per 1,000  6.376e-09   5.87e-09      1.086      0.277   -5.13e-09    1.79e-08
# =========================================================================================
# /Users/esma/miniforge3/envs/mlvu/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# /Users/esma/miniforge3/envs/mlvu/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# /Users/esma/miniforge3/envs/mlvu/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# /Users/esma/miniforge3/envs/mlvu/lib/python3.10/site-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "

# %% [markdown]
# ### **Analysis of the Negative Binomial Regression Results for Gov-to-Civilian Ratio**
#
# ### **Table**
# | Crime Type               | Gov-to-Civilian Ratio Coefficient | P-value (Ratio) | Effect of Ratio on Crime | GDP Coefficient | P-value (GDP) | Effect of GDP on Crime |
# |-------------------------|-----------------------------------|----------------|---------------------------|----------------|---------------|-------------------------|
# | **Total Homicides**      | -0.8463                          | 0.001          | Significant reduction     | -3.203e-08     | 0.000         | Significant reduction   |
# | **Total Sexual Crimes**  | -0.0394                          | 0.368          | No significant effect     | 2.318e-08      | 0.002         | Significant increase    |
# | **Total Violent Crimes** | -0.0567                          | 0.117          | No significant effect     | 2.92e-08       | 0.000         | Significant increase    |
# | **Combined Crime Rate**  | -0.0624                          | 0.058          | Borderline reduction      | 6.376e-09      | 0.277         | No significant effect   |
#
#
# ### **Summary of Key Findings:**
# - **Homicides:** A **significant negative relationship** between the gov-to-civilian ratio and homicides implies that a higher proportion of government-owned weapons can **reduce homicide rates**.
# - **Sexual and Violent Crimes:** The ratio does **not significantly influence** these crime types, though a weak protective effect is suggested for violent crimes.
# - **Combined Crime Rate:** The borderline significance suggests that the **general impact of government firearms on crime is worth further investigation**.
#
# ### **Overall Conclusion:**
# - The ratio of government-to-civilian firearms **has a clear protective effect on homicide rates** and **potentially contributes to reducing overall crime rates**.
# - However, the effect is **weak or non-significant** for sexual and violent crimes, indicating that the effectiveness of government firearm presence may depend on crime type.
# - **Economic development (GDP)** shows a mixed influence: reducing homicides but **increasing violent and sexual crime rates**, likely due to better reporting and socio-economic complexities.

# %%
# Apply log transformation to the Gov-to-Civilian Ratio
data["Log_Gov_to_Civilian_Ratio"] = np.log1p(data["Gov_to_Civilian_Ratio"])  # log(1 + x) to handle zeros

# Define crime types and titles for subplots
crime_types = ["Homicides per 1,000", "Sexual Crimes per 1,000", 
               "Violent Crimes per 1,000", "Combined Crime Rate per 1,000"]
titles = ["Homicides", "Sexual Crimes", "Violent Crimes", "Combined Crime Rate"]

# Create subplots (2 rows, 2 columns)
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
axes = axes.flatten()

# Generate scatterplots for each crime type, colored by GDP
for i, crime in enumerate(crime_types):
    sns.scatterplot(
        x=data["Log_Gov_to_Civilian_Ratio"], 
        y=data[crime], 
        hue=data["Country GDP per 1,000"], 
        palette='viridis', 
        ax=axes[i], 
        alpha=0.8, 
        legend=(i == 0)  # Show legend only for the first subplot
    )
    axes[i].set_title(titles[i])
    axes[i].set_xlabel("Log(Gov-to-Civilian Ratio)")
    axes[i].set_ylabel(crime)

# Adjust layout and add legend for the first plot
plt.tight_layout()
plt.legend(title="GDP per 1,000", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
# Out:
# /var/folders/9j/jqs2fbzx1nl_9hlbbtdrlqrr0000gn/T/ipykernel_598/3695117719.py:30: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(title="GDP per 1,000", bbox_to_anchor=(1.05, 1), loc='upper left')

# %%
# Impact of Civilian Gun Ownership
# Relationship between civilian firearms per 1,000 and crime rates
civ_gun_column = "Estimate of firearms in civilian possession per 1,000"

plt.figure(figsize=(12, 6))
sns.scatterplot(x=civ_gun_column, y='Combined Crime Rate per 1,000', data=data)
plt.title('Civilian Firearms vs Combined Crime Rate')
plt.xlabel('Civilian Firearms per 1,000')
plt.ylabel('Combined Crime Rate per 1,000')
plt.show()

# Correlation
civ_gun_correlation, _ = pearsonr(data[civ_gun_column], data['Combined Crime Rate per 1,000'])
print(f"Correlation between civilian firearms and combined crime rate: {civ_gun_correlation}")
# Out:
# Correlation between civilian firearms and combined crime rate: 0.08879425288446355
