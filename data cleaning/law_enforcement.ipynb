# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_excel("data/SAS-BP-Law-enforcement-firearms-annexe.xlsx")
dataset.columns=dataset.iloc[0]
dataset.head()
# Out:
#   Law enforcement Firearms Holdings, 2017\n(c) Small Arms Survey Unnamed: 1  \
# 0                                                ISO                Country
# 1                                                NaN                    NaN
# 2                                                NaN                    NaN
# 3                                                NaN                    NaN
# 4                                                NaN                    NaN
#
#   Unnamed: 2 Unnamed: 3  Unnamed: 4  Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0  Continent  Subregion  Population         NaN   Category     Active
# 1        NaN        NaN        2017         NaN        NaN  personnel
# 2        NaN        NaN         NaN         NaN        NaN        NaN
# 3        NaN        NaN         NaN         NaN        NaN        NaN
# 4        NaN        NaN         NaN         NaN        NaN        NaN
#
#     Unnamed: 8                                         Unnamed: 9  Unnamed: 10
# ...

# %%
#dataset = dataset.drop(["Category", "Computation method"], axis=1)
dataset
# Out:
# 0    ISO                Country Continent        Subregion Population  NaN  \
# 6    AFG            Afghanistan      Asia    Southern Asia   34169000  NaN
# 9    ALB                Albania    Europe  Southern Europe    2911000  NaN
# 10   DZA                Algeria    Africa  Northern Africa   41064000  NaN
# 15   ASM         American Samoa   Oceania        Polynesia      56000  NaN
# 16   AND                Andorra    Europe  Southern Europe      69000  NaN
# ..   ...                    ...       ...              ...        ...  ...
# 425  VGB  Virgin Islands (U.K.)  Americas              NaN      31000  NaN
# 426  VIR  Virgin Islands (U.S.)  Americas        Caribbean     107000  NaN
# 427  YEM                  Yemen      Asia     Western Asia   28120000  NaN
# 429  ZMB                 Zambia    Africa   Eastern Africa   17238000  NaN
# 430  ZWE               Zimbabwe    Africa   Eastern Africa   16338000  NaN
#
# 0    Active     Law  NaN
# 6    159600  239000  2.0
# ...

# %%
dataset.columns=["ISO", "Country", "Continent", "Subregion", "Population", "Unnamed 1", "Active personel", "Law Enforcement Firearms", "Unnamed 2"]
dataset
# Out:
#      ISO                Country Continent        Subregion Population  \
# 6    AFG            Afghanistan      Asia    Southern Asia   34169000
# 9    ALB                Albania    Europe  Southern Europe    2911000
# 10   DZA                Algeria    Africa  Northern Africa   41064000
# 15   ASM         American Samoa   Oceania        Polynesia      56000
# 16   AND                Andorra    Europe  Southern Europe      69000
# ..   ...                    ...       ...              ...        ...
# 425  VGB  Virgin Islands (U.K.)  Americas              NaN      31000
# 426  VIR  Virgin Islands (U.S.)  Americas        Caribbean     107000
# 427  YEM                  Yemen      Asia     Western Asia   28120000
# 429  ZMB                 Zambia    Africa   Eastern Africa   17238000
# 430  ZWE               Zimbabwe    Africa   Eastern Africa   16338000
#
#      Unnamed 1  Active     Law  Unnamed 2
# 6          NaN  159600  239000        2.0
# ...

# %%
dataset = dataset.drop("Unnamed 1", axis=1)

# %%
columns = list(dataset.columns)
columns[-2] = "Total firearms"
columns[-3] = "Active Personel"
dataset.columns=columns
dataset
# Out:
#      ISO                Country Continent        Subregion Population  \
# 6    AFG            Afghanistan      Asia    Southern Asia   34169000
# 9    ALB                Albania    Europe  Southern Europe    2911000
# 10   DZA                Algeria    Africa  Northern Africa   41064000
# 15   ASM         American Samoa   Oceania        Polynesia      56000
# 16   AND                Andorra    Europe  Southern Europe      69000
# ..   ...                    ...       ...              ...        ...
# 425  VGB  Virgin Islands (U.K.)  Americas              NaN      31000
# 426  VIR  Virgin Islands (U.S.)  Americas        Caribbean     107000
# 427  YEM                  Yemen      Asia     Western Asia   28120000
# 429  ZMB                 Zambia    Africa   Eastern Africa   17238000
# 430  ZWE               Zimbabwe    Africa   Eastern Africa   16338000
#
#     Active Personel Total firearms  Computation method
# 6            159600         239000                 2.0
# ...

# %%
#dataset.to_csv("law_enforcement dataset.csv")
