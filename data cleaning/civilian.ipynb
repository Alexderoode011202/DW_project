# %%
import pandas as pd
import numpy as np
from typing import List

# %%
new_data = pd.read_csv("reworked_dataset (prot 1).csv", index_col=0)

# %%
new_data
# Out:
#     Country code                Country    Region        Subregion  \
# 0            AFG            Afghanistan      Asia    Southern Asia
# 1            ALB                Albania    Europe  Southern Europe
# 2            DZA                Algeria    Africa  Northern Africa
# 3            ASM         American Samoa   Oceania        Polynesia
# 4            AND                Andorra    Europe  Southern Europe
# ..           ...                    ...       ...              ...
# 225          VGB  Virgin Islands (U.K.)  Americas        Caribbean
# 226          VIR  Virgin Islands (U.S.)  Americas        Caribbean
# 227          YEM                  Yemen      Asia     Western Asia
# 228          ZMB                 Zambia    Africa   Eastern Africa
# 229          ZWE               Zimbabwe    Africa   Eastern Africa
#
#      Population 2017 Estimate of firearms in civilian possession  \
# 0         34169000.0                                     4270000
# ...

# %%
loose_ends = new_data.isna().any(axis=1)

# %%
loose_ends = loose_ends.replace(False, pd.NA).dropna().index

# %%
print(list(new_data.iloc[loose_ends]["Country"]))
# Out:
# ['Afghanistan', 'Angola', 'Aruba', 'Azerbaijan', 'Bahrain', 'Benin', 'Bermuda', 'Brunei Darussalam', 'Burkina Faso', 'Burundi', 'Cabo Verde (Cape Verde)', 'Cambodia', 'Cameroon', 'Central African Republic', 'Chad', 'China, Macao SAR', 'Christmas Island', 'Comoros', 'Congo, Republic of', 'Curaçao', 'Djibouti', 'Dominica', 'Equatorial Guinea', 'Eritrea', 'Ethiopia', 'Faroe Islands', 'French Guiana', 'French Polynesia', 'Gabon', 'Gambia', 'Gibraltar', 'Greenland', 'Grenada', 'Guam', 'Guinea', 'Guinea-Bissau', 'Holy See', 'Hong Kong SAR, China', 'Iran, Islamic Republic of', 'Iraq', 'Kiribati', 'Korea, DPR (North)', "Lao People's Democratic Republic", 'Lebanon', 'Lesotho', 'Liberia', 'Libya', 'Liechtenstein', 'Madagascar', 'Maldives', 'Mali', 'Marshall Islands', 'Martinique', 'Mauritania', 'Mauritius', 'Micronesia, Fed. Sts.', 'Monaco', 'Montserrat', 'Morocco', 'Myanmar', 'Nauru', 'Nigeria', 'Northern Mariana Islands', 'Oman', 'Palau', 'Palestinian Territories', 'Puerto Rico', 'Puntland',
# ...
